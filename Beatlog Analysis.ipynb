# %%
import pandas as pd
import numpy as np
import os
import sklearn as 

# to make this notebook's output stable across runs
np.random.seed(42)

# %%
def load_data(init_path='/Users/blakenicholson/Documents/Personal/Coding',filename='BEATLOG IMPORT.csv'):
    csv_path = os.path.join(init_path, filename)
    return pd.read_csv(csv_path, encoding = "latin-1", error_bad_lines=False)

employee_data = load_data()

employee_data.head()
# Out:
#    ID    Beat Name    File Name  Tempo   Genre Created Date Status  \
# 0   1  1980shouse1  1980shouse1  115.0   House          NaN    NaN
# 1   2       36shit       36shit  160.0    Juke          NaN   LOST
# 2   3      5:01:32      5:01:32   87.0  Hiphop          NaN    NaN
# 3   4  4:29:2012#2  4:29:2012#2   86.0     NaN          NaN    NaN
# 4   5           5%           5%  124.0    Club          NaN    NaN
#
#   Collaborators Remix               Notes Racked Release_Project
# 0           NaN   NaN                 NaN    NaN             NaN
# 1           NaN   NaN  Finish arrangement    NaN             NaN
# 2           NaN   NaN                 NaN    NaN             NaN
# 3           NaN   NaN                 NaN    NaN             NaN
# 4           NaN   NaN                 NaN    NaN             NaN
